# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import sklearn.metrics as sm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('co2.csv')

# %%
df.describe()
# Out:
#            engine     cylandr    fuelcomb        out1
# count  500.000000  500.000000  500.000000  500.000000
# mean     3.600400    6.132000   12.476600  268.026000
# std      1.478191    1.832291    3.943025   67.099673
# min      1.000000    4.000000    4.800000  110.000000
# 25%      2.000000    4.000000    9.500000  217.000000
# 50%      3.600000    6.000000   11.650000  260.000000
# 75%      5.000000    8.000000   14.800000  317.000000
# max      6.800000   12.000000   25.800000  488.000000

# %%
sns.countplot(x='out1', data=df)
# Out:
# <Axes: xlabel='out1', ylabel='count'>

# %%
plt.subplots(figsize=(9,9))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
x = df.drop("out1", axis=1)
x = x.drop("fuelcomb", axis=1)
x = x.drop("cylandr", axis=1)
y = df.out1

# %%
x
# Out:
#      engine
# 0       2.0
# 1       2.4
# 2       1.5
# 3       3.5
# 4       3.5
# ..      ...
# 495     1.5
# 496     1.5
# 497     1.5
# 498     3.5
# 499     3.6
#
# [500 rows x 1 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train
# Out:
#      engine
# 450     4.8
# 480     5.3
# 69      4.0
# 318     2.0
# 197     1.4
# ..      ...
# 229     2.5
# 30      3.0
# 84      2.0
# 237     4.3
# 277     3.6
#
# [400 rows x 1 columns]

# %%
x_test
# Out:
#      engine
# 248     1.4
# 442     5.3
# 362     5.4
# 15      4.7
# 369     3.5
# ..      ...
# 307     3.6
# 172     3.6
# 319     2.4
# 221     5.3
# 423     3.5
#
# [100 rows x 1 columns]

# %%
model= linear_model.LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
out_robot = model.predict(x_test)

# %%
out_robot
# Out:
# array([178.50707097, 337.25665381, 341.32715594, 312.83364107,
#        263.98761558, 398.31418568, 202.93008371, 300.62213469,
#        268.0581177 , 263.98761558, 373.89117293, 382.03217718,
#        194.78907946, 268.0581177 , 373.89117293, 202.93008371,
#        337.25665381, 337.25665381, 223.28259433, 316.90414319,
#        268.0581177 , 373.89117293, 202.93008371, 268.0581177 ,
#        263.98761558, 337.25665381, 353.53866231, 202.93008371,
#        337.25665381, 243.63510495, 268.0581177 , 337.25665381,
#        365.75016868, 353.53866231, 162.22506247, 300.62213469,
#        268.0581177 , 186.64807521, 202.93008371, 382.03217718,
#        202.93008371, 268.0581177 , 268.0581177 , 268.0581177 ,
#        341.32715594, 373.89117293, 243.63510495, 337.25665381,
#        284.3401262 , 202.93008371, 341.32715594, 373.89117293,
#        365.75016868, 178.50707097, 202.93008371, 186.64807521,
#        268.0581177 , 202.93008371, 373.89117293, 178.50707097,
#        337.25665381, 263.98761558, 337.25665381, 268.0581177 ,
#        337.25665381, 300.62213469, 219.21209221, 337.25665381,
#        243.63510495, 300.62213469, 194.78907946, 219.21209221,
#        202.93008371, 292.48113045, 219.21209221, 268.0581177 ,
#        272.12861982, 178.50707097, 178.50707097, 365.75016868,
#        243.63510495, 219.21209221, 337.25665381, 341.32715594,
#        243.63510495, 325.04514744, 263.98761558, 268.0581177 ,
#        272.12861982, 202.93008371, 325.04514744, 337.25665381,
#        296.55163257, 268.0581177 , 268.0581177 , 268.0581177 ,
#        268.0581177 , 219.21209221, 337.25665381, 263.98761558])

# %%
y_test
# Out:
# 248    173
# 442    362
# 362    346
# 15     338
# 369    292
#       ...
# 307    251
# 172    262
# 319    212
# 221    380
# 423    271
# Name: out1, Length: 100, dtype: int64

# %%
x_test
# Out:
#      engine
# 248     1.4
# 442     5.3
# 362     5.4
# 15      4.7
# 369     3.5
# ..      ...
# 307     3.6
# 172     3.6
# 319     2.4
# 221     5.3
# 423     3.5
#
# [100 rows x 1 columns]

# %%
plt.scatter(x_test, y_test, color='red')
plt.show()

# %%
plt.scatter(x_test, y_test, color='red')
plt.plot(x_test, y_test_pred, color='black', linewidth=2)
plt.show()

# %%
p206=np.array([[1.36]])

# %%
co2=model.predict(p206)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
co2
# Out:
# array([176.87887012])
